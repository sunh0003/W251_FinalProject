# %%
! rmdir /notebooks/data7cls_randomsplit/validation/.ipynb_checkpoints
# Out:
# rmdir: failed to remove '/notebooks/data7cls_randomsplit/validation/.ipynb_checkpoints': No such file or directory

# %% [markdown]
# ### Re-run from here!

# %%
import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
# input path for the images

base_path = '/notebooks/data7cls_randomsplit/'

# %%
for expression in os.listdir(base_path + "train/"):
    print (expression)
# Out:
# distracted
# sad
# confused
# angry
# surprise
# happy
# neutral

# %%
# display some images for every different expression

# size of the image: 48*48 pixels
pic_size = 48



plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
# count number of train images for each expression

for expression in os.listdir(base_path + "train"):
    print(str(len(os.listdir(base_path + "train/" + expression))) + " " + expression + " images")
# Out:
# 522 distracted images
# 4938 sad images
# 643 confused images
# 3993 angry images
# 3205 surprise images
# 7164 happy images
# 4982 neutral images

# %%
# count number of validation images for each expression

for expression in os.listdir(base_path + "validation"):
    print(str(len(os.listdir(base_path + "validation/" + expression))) + " " + expression + " images")
# Out:
# 132 distracted images
# 1139 sad images
# 169 confused images
# 960 angry images
# 797 surprise images
# 1825 happy images
# 1216 neutral images

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 25446 images belonging to 7 classes.
# Found 6236 images belonging to 7 classes.

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# %%time

# number of epochs to train the NN
epochs = 150

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights_7c_150e.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/150
# 198/198 [==============================] - 935s 5s/step - loss: 1.8712 - acc: 0.2741 - val_loss: 1.5048 - val_acc: 0.3877
#
# Epoch 00001: val_acc improved from -inf to 0.38770, saving model to model_weights_7c_150e.h5
# Epoch 2/150
# 198/198 [==============================] - 919s 5s/step - loss: 1.5999 - acc: 0.3618 - val_loss: 1.4630 - val_acc: 0.4145
#
# Epoch 00002: val_acc improved from 0.38770 to 0.41454, saving model to model_weights_7c_150e.h5
# Epoch 3/150
# 198/198 [==============================] - 917s 5s/step - loss: 1.4745 - acc: 0.4117 - val_loss: 1.4457 - val_acc: 0.4299
#
# Epoch 00003: val_acc improved from 0.41454 to 0.42993, saving model to model_weights_7c_150e.h5
# Epoch 4/150
# 198/198 [==============================] - 946s 5s/step - loss: 1.3897 - acc: 0.4423 - val_loss: 1.4274 - val_acc: 0.4512
#
# Epoch 00004: val_acc improved from 0.42993 to 0.45121, saving model to model_weights_7c_150e.h5
# Epoch 5/150
# 198/198 [==============================] - 914s 5s/step - loss: 1.3312 - acc: 0.4668 - val_loss: 1.3910 - val_acc: 0.4705
#
# Epoch 00005: val_acc improved from 0.45121 to 0.47053, saving model to model_weights_7c_150e.h5
# Epoch 6/150
# 198/198 [==============================] - 916s 5s/step - loss: 1.2646 - acc: 0.4942 - val_loss: 1.2092 - val_acc: 0.5129
#
# Epoch 00006: val_acc improved from 0.47053 to 0.51293, saving model to model_weights_7c_150e.h5
# Epoch 7/150
# 198/198 [==============================] - 912s 5s/step - loss: 1.2211 - acc: 0.5103 - val_loss: 1.1128 - val_acc: 0.5524
#
# Epoch 00007: val_acc improved from 0.51293 to 0.55239, saving model to model_weights_7c_150e.h5
# Epoch 8/150
# 198/198 [==============================] - 917s 5s/step - loss: 1.1604 - acc: 0.5386 - val_loss: 1.2031 - val_acc: 0.5352
#
# Epoch 00008: val_acc did not improve from 0.55239
# Epoch 9/150
# 198/198 [==============================] - 916s 5s/step - loss: 1.1330 - acc: 0.5442 - val_loss: 1.1019 - val_acc: 0.5622
#
# Epoch 00009: val_acc improved from 0.55239 to 0.56221, saving model to model_weights_7c_150e.h5
# Epoch 10/150
# 198/198 [==============================] - 918s 5s/step - loss: 1.0915 - acc: 0.5645 - val_loss: 1.1493 - val_acc: 0.5560
#
# Epoch 00010: val_acc did not improve from 0.56221
# Epoch 11/150
# 198/198 [==============================] - 911s 5s/step - loss: 1.0600 - acc: 0.5775 - val_loss: 1.0549 - val_acc: 0.5815
#
# Epoch 00011: val_acc improved from 0.56221 to 0.58153, saving model to model_weights_7c_150e.h5
# Epoch 12/150
# 198/198 [==============================] - 915s 5s/step - loss: 1.0267 - acc: 0.5896 - val_loss: 1.0078 - val_acc: 0.6022
#
# Epoch 00012: val_acc improved from 0.58153 to 0.60216, saving model to model_weights_7c_150e.h5
# Epoch 13/150
# 198/198 [==============================] - 923s 5s/step - loss: 1.0114 - acc: 0.5965 - val_loss: 0.9517 - val_acc: 0.6246
#
# Epoch 00013: val_acc improved from 0.60216 to 0.62459, saving model to model_weights_7c_150e.h5
# Epoch 14/150
# 198/198 [==============================] - 915s 5s/step - loss: 0.9734 - acc: 0.6138 - val_loss: 0.9305 - val_acc: 0.6385
#
# Epoch 00014: val_acc improved from 0.62459 to 0.63851, saving model to model_weights_7c_150e.h5
# Epoch 15/150
# 198/198 [==============================] - 915s 5s/step - loss: 0.9530 - acc: 0.6253 - val_loss: 0.9084 - val_acc: 0.6413
#
# Epoch 00015: val_acc improved from 0.63851 to 0.64129, saving model to model_weights_7c_150e.h5
# Epoch 16/150
# 198/198 [==============================] - 516s 3s/step - loss: 0.9360 - acc: 0.6280 - val_loss: 0.9297 - val_acc: 0.6328
#
# Epoch 00016: val_acc did not improve from 0.64129
# Epoch 17/150
# 198/198 [==============================] - 477s 2s/step - loss: 0.9195 - acc: 0.6360 - val_loss: 0.9791 - val_acc: 0.6176
#
# Epoch 00017: val_acc did not improve from 0.64129
# Epoch 18/150
# 198/198 [==============================] - 475s 2s/step - loss: 0.8958 - acc: 0.6459 - val_loss: 0.8912 - val_acc: 0.6534
#
# Epoch 00018: val_acc improved from 0.64129 to 0.65341, saving model to model_weights_7c_150e.h5
# Epoch 19/150
# 198/198 [==============================] - 478s 2s/step - loss: 0.8818 - acc: 0.6531 - val_loss: 0.9014 - val_acc: 0.6500
#
# Epoch 00019: val_acc did not improve from 0.65341
# Epoch 20/150
# 198/198 [==============================] - 478s 2s/step - loss: 0.8646 - acc: 0.6572 - val_loss: 0.8550 - val_acc: 0.6734
#
# Epoch 00020: val_acc improved from 0.65341 to 0.67338, saving model to model_weights_7c_150e.h5
# Epoch 21/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.8486 - acc: 0.6655 - val_loss: 0.8950 - val_acc: 0.6550
#
# Epoch 00021: val_acc did not improve from 0.67338
# Epoch 22/150
# 198/198 [==============================] - 478s 2s/step - loss: 0.8247 - acc: 0.6766 - val_loss: 0.8538 - val_acc: 0.6729
#
# Epoch 00022: val_acc did not improve from 0.67338
# Epoch 23/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.8146 - acc: 0.6806 - val_loss: 0.8674 - val_acc: 0.6626
#
# Epoch 00023: val_acc did not improve from 0.67338
# Epoch 24/150
# 198/198 [==============================] - 478s 2s/step - loss: 0.7981 - acc: 0.6880 - val_loss: 0.8672 - val_acc: 0.6775
#
# Epoch 00024: val_acc improved from 0.67338 to 0.67747, saving model to model_weights_7c_150e.h5
# Epoch 25/150
# 198/198 [==============================] - 477s 2s/step - loss: 0.7810 - acc: 0.6967 - val_loss: 0.8374 - val_acc: 0.6804
#
# Epoch 00025: val_acc improved from 0.67747 to 0.68042, saving model to model_weights_7c_150e.h5
# Epoch 26/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.7600 - acc: 0.7014 - val_loss: 0.8279 - val_acc: 0.6819
#
# Epoch 00026: val_acc improved from 0.68042 to 0.68189, saving model to model_weights_7c_150e.h5
# Epoch 27/150
# 198/198 [==============================] - 474s 2s/step - loss: 0.7576 - acc: 0.7045 - val_loss: 0.8349 - val_acc: 0.6889
#
# Epoch 00027: val_acc improved from 0.68189 to 0.68893, saving model to model_weights_7c_150e.h5
# Epoch 28/150
# 198/198 [==============================] - 477s 2s/step - loss: 0.7302 - acc: 0.7155 - val_loss: 0.8029 - val_acc: 0.6953
#
# Epoch 00028: val_acc improved from 0.68893 to 0.69532, saving model to model_weights_7c_150e.h5
# Epoch 29/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.7159 - acc: 0.7224 - val_loss: 0.8316 - val_acc: 0.6916
#
# Epoch 00029: val_acc did not improve from 0.69532
# Epoch 30/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.7119 - acc: 0.7236 - val_loss: 0.8181 - val_acc: 0.6948
#
# Epoch 00030: val_acc did not improve from 0.69532
# Epoch 31/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.6957 - acc: 0.7304 - val_loss: 0.8339 - val_acc: 0.6932
#
# Epoch 00031: val_acc did not improve from 0.69532
# Epoch 32/150
# 198/198 [==============================] - 477s 2s/step - loss: 0.6783 - acc: 0.7365 - val_loss: 0.8323 - val_acc: 0.6868
#
# Epoch 00032: val_acc did not improve from 0.69532
# Epoch 33/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.6616 - acc: 0.7446 - val_loss: 0.8028 - val_acc: 0.7028
#
# Epoch 00033: val_acc improved from 0.69532 to 0.70285, saving model to model_weights_7c_150e.h5
# Epoch 34/150
# 198/198 [==============================] - 484s 2s/step - loss: 0.6578 - acc: 0.7455 - val_loss: 0.7950 - val_acc: 0.7046
#
# Epoch 00034: val_acc improved from 0.70285 to 0.70465, saving model to model_weights_7c_150e.h5
# Epoch 35/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.6421 - acc: 0.7533 - val_loss: 0.8080 - val_acc: 0.7017
#
# Epoch 00035: val_acc did not improve from 0.70465
# Epoch 36/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.6303 - acc: 0.7579 - val_loss: 0.8257 - val_acc: 0.6973
#
# Epoch 00036: val_acc did not improve from 0.70465
# Epoch 37/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.6185 - acc: 0.7603 - val_loss: 0.8042 - val_acc: 0.7091
#
# Epoch 00037: val_acc improved from 0.70465 to 0.70907, saving model to model_weights_7c_150e.h5
# Epoch 38/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.5977 - acc: 0.7692 - val_loss: 0.8076 - val_acc: 0.7012
#
# Epoch 00038: val_acc did not improve from 0.70907
# Epoch 39/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.6006 - acc: 0.7696 - val_loss: 0.7836 - val_acc: 0.7174
#
# Epoch 00039: val_acc improved from 0.70907 to 0.71742, saving model to model_weights_7c_150e.h5
# Epoch 40/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.5795 - acc: 0.7773 - val_loss: 0.8161 - val_acc: 0.7089
#
# Epoch 00040: val_acc did not improve from 0.71742
# Epoch 41/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.5637 - acc: 0.7835 - val_loss: 0.8081 - val_acc: 0.7145
#
# Epoch 00041: val_acc did not improve from 0.71742
# Epoch 42/150
# 198/198 [==============================] - 491s 2s/step - loss: 0.5525 - acc: 0.7882 - val_loss: 0.7974 - val_acc: 0.7151
#
# Epoch 00042: val_acc did not improve from 0.71742
# Epoch 43/150
# 198/198 [==============================] - 572s 3s/step - loss: 0.5410 - acc: 0.7910 - val_loss: 0.7704 - val_acc: 0.7250
#
# Epoch 00043: val_acc improved from 0.71742 to 0.72495, saving model to model_weights_7c_150e.h5
# Epoch 44/150
# 198/198 [==============================] - 478s 2s/step - loss: 0.5299 - acc: 0.7979 - val_loss: 0.8008 - val_acc: 0.7150
#
# Epoch 00044: val_acc did not improve from 0.72495
# Epoch 45/150
# 198/198 [==============================] - 481s 2s/step - loss: 0.5195 - acc: 0.8037 - val_loss: 0.7759 - val_acc: 0.7292
#
# Epoch 00045: val_acc improved from 0.72495 to 0.72921, saving model to model_weights_7c_150e.h5
# Epoch 46/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.5072 - acc: 0.8064 - val_loss: 0.7965 - val_acc: 0.7238
#
# Epoch 00046: val_acc did not improve from 0.72921
# Epoch 47/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.4911 - acc: 0.8112 - val_loss: 0.8056 - val_acc: 0.7141
#
# Epoch 00047: val_acc did not improve from 0.72921
# Epoch 48/150
# 198/198 [==============================] - 481s 2s/step - loss: 0.4865 - acc: 0.8151 - val_loss: 0.8323 - val_acc: 0.7091
#
# Epoch 00048: val_acc did not improve from 0.72921
# Epoch 49/150
# 198/198 [==============================] - 481s 2s/step - loss: 0.4746 - acc: 0.8188 - val_loss: 0.8331 - val_acc: 0.7181
#
# Epoch 00049: val_acc did not improve from 0.72921
# Epoch 50/150
# 198/198 [==============================] - 482s 2s/step - loss: 0.4653 - acc: 0.8221 - val_loss: 0.8283 - val_acc: 0.7091
#
# Epoch 00050: val_acc did not improve from 0.72921
# Epoch 51/150
# 198/198 [==============================] - 482s 2s/step - loss: 0.4510 - acc: 0.8268 - val_loss: 0.8520 - val_acc: 0.7194
#
# Epoch 00051: val_acc did not improve from 0.72921
# Epoch 52/150
# 198/198 [==============================] - 482s 2s/step - loss: 0.4457 - acc: 0.8324 - val_loss: 0.7909 - val_acc: 0.7230
#
# Epoch 00052: val_acc did not improve from 0.72921
# Epoch 53/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.4306 - acc: 0.8363 - val_loss: 0.8260 - val_acc: 0.7233
#
# Epoch 00053: val_acc did not improve from 0.72921
# Epoch 54/150
# 198/198 [==============================] - 482s 2s/step - loss: 0.4228 - acc: 0.8389 - val_loss: 0.8599 - val_acc: 0.7081
#
# Epoch 00054: val_acc did not improve from 0.72921
# Epoch 55/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.4101 - acc: 0.8451 - val_loss: 0.8399 - val_acc: 0.7223
#
# Epoch 00055: val_acc did not improve from 0.72921
# Epoch 56/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.4037 - acc: 0.8471 - val_loss: 0.8704 - val_acc: 0.7119
#
# Epoch 00056: val_acc did not improve from 0.72921
# Epoch 57/150
# 198/198 [==============================] - 480s 2s/step - loss: 0.3942 - acc: 0.8522 - val_loss: 0.8843 - val_acc: 0.7148
#
# Epoch 00057: val_acc did not improve from 0.72921
# Epoch 58/150
# 198/198 [==============================] - 481s 2s/step - loss: 0.3867 - acc: 0.8529 - val_loss: 0.8816 - val_acc: 0.7119
#
# Epoch 00058: val_acc did not improve from 0.72921
# Epoch 59/150
# 198/198 [==============================] - 688s 3s/step - loss: 0.3698 - acc: 0.8588 - val_loss: 0.8435 - val_acc: 0.7241
#
# Epoch 00059: val_acc did not improve from 0.72921
# Epoch 60/150
# 198/198 [==============================] - 843s 4s/step - loss: 0.3620 - acc: 0.8621 - val_loss: 0.8406 - val_acc: 0.7302
#
# Epoch 00060: val_acc improved from 0.72921 to 0.73019, saving model to model_weights_7c_150e.h5
# Epoch 61/150
# 198/198 [==============================] - 843s 4s/step - loss: 0.3632 - acc: 0.8647 - val_loss: 0.8559 - val_acc: 0.7228
#
# Epoch 00061: val_acc did not improve from 0.73019
# Epoch 62/150
# 198/198 [==============================] - 845s 4s/step - loss: 0.3540 - acc: 0.8656 - val_loss: 0.8517 - val_acc: 0.7294
#
# Epoch 00062: val_acc did not improve from 0.73019
# Epoch 63/150
# 198/198 [==============================] - 842s 4s/step - loss: 0.3339 - acc: 0.8743 - val_loss: 0.9866 - val_acc: 0.7060
#
# Epoch 00063: val_acc did not improve from 0.73019
# Epoch 64/150
# 198/198 [==============================] - 845s 4s/step - loss: 0.3350 - acc: 0.8733 - val_loss: 0.9416 - val_acc: 0.7199
#
# Epoch 00064: val_acc did not improve from 0.73019
# Epoch 65/150
# 198/198 [==============================] - 845s 4s/step - loss: 0.3227 - acc: 0.8793 - val_loss: 0.8644 - val_acc: 0.7295
#
# Epoch 00065: val_acc did not improve from 0.73019
# Epoch 66/150
# 198/198 [==============================] - 844s 4s/step - loss: 0.3295 - acc: 0.8773 - val_loss: 0.8733 - val_acc: 0.7271
#
# Epoch 00066: val_acc did not improve from 0.73019
# Epoch 67/150
# 198/198 [==============================] - 843s 4s/step - loss: 0.3168 - acc: 0.8799 - val_loss: 0.9225 - val_acc: 0.7191
#
# Epoch 00067: val_acc did not improve from 0.73019
# Epoch 68/150
# 198/198 [==============================] - 845s 4s/step - loss: 0.3048 - acc: 0.8847 - val_loss: 0.8760 - val_acc: 0.7331
#
# Epoch 00068: val_acc improved from 0.73019 to 0.73314, saving model to model_weights_7c_150e.h5
# Epoch 69/150
# 198/198 [==============================] - 838s 4s/step - loss: 0.3008 - acc: 0.8884 - val_loss: 0.9133 - val_acc: 0.7202
#
# Epoch 00069: val_acc did not improve from 0.73314
# Epoch 70/150
# 198/198 [==============================] - 844s 4s/step - loss: 0.2989 - acc: 0.8876 - val_loss: 0.9672 - val_acc: 0.7228
#
# Epoch 00070: val_acc did not improve from 0.73314
# Epoch 71/150
# 198/198 [==============================] - 844s 4s/step - loss: 0.2813 - acc: 0.8946 - val_loss: 0.9467 - val_acc: 0.7233
#
# Epoch 00071: val_acc did not improve from 0.73314
# Epoch 72/150
# 198/198 [==============================] - 844s 4s/step - loss: 0.2812 - acc: 0.8942 - val_loss: 0.9476 - val_acc: 0.7163
#
# Epoch 00072: val_acc did not improve from 0.73314
# Epoch 73/150
# 198/198 [==============================] - 850s 4s/step - loss: 0.2709 - acc: 0.8963 - val_loss: 0.9543 - val_acc: 0.7282
#
# Epoch 00073: val_acc did not improve from 0.73314
# Epoch 74/150
# 198/198 [==============================] - 849s 4s/step - loss: 0.2761 - acc: 0.8977 - val_loss: 0.9542 - val_acc: 0.7246
#
# Epoch 00074: val_acc did not improve from 0.73314
# Epoch 75/150
# 198/198 [==============================] - 842s 4s/step - loss: 0.2591 - acc: 0.9038 - val_loss: 0.9764 - val_acc: 0.7217
#
# Epoch 00075: val_acc did not improve from 0.73314
# Epoch 76/150
# 198/198 [==============================] - 846s 4s/step - loss: 0.2536 - acc: 0.9051 - val_loss: 0.9338 - val_acc: 0.7264
#
# Epoch 00076: val_acc did not improve from 0.73314
# Epoch 77/150
# 198/198 [==============================] - 843s 4s/step - loss: 0.2538 - acc: 0.9063 - val_loss: 1.0372 - val_acc: 0.7076
#
# Epoch 00077: val_acc did not improve from 0.73314
# Epoch 78/150
# 198/198 [==============================] - 848s 4s/step - loss: 0.2443 - acc: 0.9086 - val_loss: 1.0008 - val_acc: 0.7204
#
# Epoch 00078: val_acc did not improve from 0.73314
# Epoch 79/150
# 198/198 [==============================] - 847s 4s/step - loss: 0.2377 - acc: 0.9117 - val_loss: 0.9950 - val_acc: 0.7225
#
# Epoch 00079: val_acc did not improve from 0.73314
# Epoch 80/150
# 198/198 [==============================] - 847s 4s/step - loss: 0.2400 - acc: 0.9097 - val_loss: 1.0054 - val_acc: 0.7227
#
# Epoch 00080: val_acc did not improve from 0.73314
# Epoch 81/150
# 198/198 [==============================] - 844s 4s/step - loss: 0.2320 - acc: 0.9139 - val_loss: 1.0127 - val_acc: 0.7177
#
# Epoch 00081: val_acc did not improve from 0.73314
# Epoch 82/150
# 198/198 [==============================] - 845s 4s/step - loss: 0.2238 - acc: 0.9169 - val_loss: 0.9777 - val_acc: 0.7258
#
# Epoch 00082: val_acc did not improve from 0.73314
# Epoch 83/150
# 198/198 [==============================] - 598s 3s/step - loss: 0.2152 - acc: 0.9200 - val_loss: 1.0199 - val_acc: 0.7176
#
# Epoch 00083: val_acc did not improve from 0.73314
# Epoch 84/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.2221 - acc: 0.9188 - val_loss: 1.0318 - val_acc: 0.7179
#
# Epoch 00084: val_acc did not improve from 0.73314
# Epoch 85/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.2158 - acc: 0.9211 - val_loss: 1.0781 - val_acc: 0.7181
#
# Epoch 00085: val_acc did not improve from 0.73314
# Epoch 86/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.2085 - acc: 0.9239 - val_loss: 1.0087 - val_acc: 0.7225
#
# Epoch 00086: val_acc did not improve from 0.73314
# Epoch 87/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.2031 - acc: 0.9250 - val_loss: 0.9995 - val_acc: 0.7256
#
# Epoch 00087: val_acc did not improve from 0.73314
# Epoch 88/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1990 - acc: 0.9269 - val_loss: 1.0870 - val_acc: 0.7251
#
# Epoch 00088: val_acc did not improve from 0.73314
# Epoch 89/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1934 - acc: 0.9292 - val_loss: 1.0427 - val_acc: 0.7228
#
# Epoch 00089: val_acc did not improve from 0.73314
# Epoch 90/150
# 198/198 [==============================] - 483s 2s/step - loss: 0.1984 - acc: 0.9263 - val_loss: 1.0976 - val_acc: 0.7143
#
# Epoch 00090: val_acc did not improve from 0.73314
# Epoch 91/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1892 - acc: 0.9317 - val_loss: 1.0298 - val_acc: 0.7300
#
# Epoch 00091: val_acc did not improve from 0.73314
# Epoch 92/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1900 - acc: 0.9309 - val_loss: 1.0401 - val_acc: 0.7281
#
# Epoch 00092: val_acc did not improve from 0.73314
# Epoch 93/150
# 198/198 [==============================] - 485s 2s/step - loss: 0.1843 - acc: 0.9330 - val_loss: 1.1028 - val_acc: 0.7240
#
# Epoch 00093: val_acc did not improve from 0.73314
# Epoch 94/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1760 - acc: 0.9350 - val_loss: 1.1197 - val_acc: 0.7199
#
# Epoch 00094: val_acc did not improve from 0.73314
# Epoch 95/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1732 - acc: 0.9358 - val_loss: 1.0298 - val_acc: 0.7330
#
# Epoch 00095: val_acc did not improve from 0.73314
# Epoch 96/150
# 198/198 [==============================] - 515s 3s/step - loss: 0.1739 - acc: 0.9365 - val_loss: 1.0877 - val_acc: 0.7268
#
# Epoch 00096: val_acc did not improve from 0.73314
# Epoch 97/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1729 - acc: 0.9379 - val_loss: 1.0867 - val_acc: 0.7308
#
# Epoch 00097: val_acc did not improve from 0.73314
# Epoch 98/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1691 - acc: 0.9380 - val_loss: 1.1288 - val_acc: 0.7245
#
# Epoch 00098: val_acc did not improve from 0.73314
# Epoch 99/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1657 - acc: 0.9385 - val_loss: 1.0775 - val_acc: 0.7269
#
# Epoch 00099: val_acc did not improve from 0.73314
# Epoch 100/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1683 - acc: 0.9372 - val_loss: 1.0796 - val_acc: 0.7243
#
# Epoch 00100: val_acc did not improve from 0.73314
# Epoch 101/150
# 198/198 [==============================] - 484s 2s/step - loss: 0.1602 - acc: 0.9409 - val_loss: 1.1337 - val_acc: 0.7254
#
# Epoch 00101: val_acc did not improve from 0.73314
# Epoch 102/150
# 198/198 [==============================] - 493s 2s/step - loss: 0.1556 - acc: 0.9445 - val_loss: 1.1178 - val_acc: 0.7150
#
# Epoch 00102: val_acc did not improve from 0.73314
# Epoch 103/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1561 - acc: 0.9427 - val_loss: 1.1458 - val_acc: 0.7212
#
# Epoch 00103: val_acc did not improve from 0.73314
# Epoch 104/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1518 - acc: 0.9457 - val_loss: 1.1892 - val_acc: 0.7217
#
# Epoch 00104: val_acc did not improve from 0.73314
# Epoch 105/150
# 198/198 [==============================] - 495s 3s/step - loss: 0.1446 - acc: 0.9477 - val_loss: 1.2068 - val_acc: 0.7089
#
# Epoch 00105: val_acc did not improve from 0.73314
# Epoch 106/150
# 198/198 [==============================] - 513s 3s/step - loss: 0.1433 - acc: 0.9484 - val_loss: 1.1103 - val_acc: 0.7276
#
# Epoch 00106: val_acc did not improve from 0.73314
# Epoch 107/150
# 198/198 [==============================] - 511s 3s/step - loss: 0.1417 - acc: 0.9483 - val_loss: 1.1033 - val_acc: 0.7343
#
# Epoch 00107: val_acc improved from 0.73314 to 0.73428, saving model to model_weights_7c_150e.h5
# Epoch 108/150
# 198/198 [==============================] - 512s 3s/step - loss: 0.1368 - acc: 0.9499 - val_loss: 1.1484 - val_acc: 0.7240
#
# Epoch 00108: val_acc did not improve from 0.73428
# Epoch 109/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1422 - acc: 0.9498 - val_loss: 1.1283 - val_acc: 0.7248
#
# Epoch 00109: val_acc did not improve from 0.73428
# Epoch 110/150
# 198/198 [==============================] - 484s 2s/step - loss: 0.1343 - acc: 0.9511 - val_loss: 1.1575 - val_acc: 0.7218
#
# Epoch 00110: val_acc did not improve from 0.73428
# Epoch 111/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1309 - acc: 0.9524 - val_loss: 1.1554 - val_acc: 0.7323
#
# Epoch 00111: val_acc did not improve from 0.73428
# Epoch 112/150
# 198/198 [==============================] - 496s 3s/step - loss: 0.1373 - acc: 0.9503 - val_loss: 1.1356 - val_acc: 0.7294
#
# Epoch 00112: val_acc did not improve from 0.73428
# Epoch 113/150
# 198/198 [==============================] - 505s 3s/step - loss: 0.1331 - acc: 0.9519 - val_loss: 1.1871 - val_acc: 0.7174
#
# Epoch 00113: val_acc did not improve from 0.73428
# Epoch 114/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1286 - acc: 0.9534 - val_loss: 1.1886 - val_acc: 0.7286
#
# Epoch 00114: val_acc did not improve from 0.73428
# Epoch 115/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1293 - acc: 0.9525 - val_loss: 1.1728 - val_acc: 0.7312
#
# Epoch 00115: val_acc did not improve from 0.73428
# Epoch 116/150
# 198/198 [==============================] - 489s 2s/step - loss: 0.1300 - acc: 0.9546 - val_loss: 1.1789 - val_acc: 0.7295
#
# Epoch 00116: val_acc did not improve from 0.73428
# Epoch 117/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1182 - acc: 0.9568 - val_loss: 1.1681 - val_acc: 0.7295
#
# Epoch 00117: val_acc did not improve from 0.73428
# Epoch 118/150
# 198/198 [==============================] - 489s 2s/step - loss: 0.1158 - acc: 0.9588 - val_loss: 1.2214 - val_acc: 0.7259
#
# Epoch 00118: val_acc did not improve from 0.73428
# Epoch 119/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1198 - acc: 0.9573 - val_loss: 1.2753 - val_acc: 0.7220
#
# Epoch 00119: val_acc did not improve from 0.73428
# Epoch 120/150
# 198/198 [==============================] - 490s 2s/step - loss: 0.1106 - acc: 0.9596 - val_loss: 1.2201 - val_acc: 0.7233
#
# Epoch 00120: val_acc did not improve from 0.73428
# Epoch 121/150
# 198/198 [==============================] - 489s 2s/step - loss: 0.1154 - acc: 0.9571 - val_loss: 1.1870 - val_acc: 0.7205
#
# Epoch 00121: val_acc did not improve from 0.73428
# Epoch 122/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.1124 - acc: 0.9599 - val_loss: 1.2459 - val_acc: 0.7264
#
# Epoch 00122: val_acc did not improve from 0.73428
# Epoch 123/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1076 - acc: 0.9615 - val_loss: 1.2261 - val_acc: 0.7286
#
# Epoch 00123: val_acc did not improve from 0.73428
# Epoch 124/150
# 198/198 [==============================] - 489s 2s/step - loss: 0.1146 - acc: 0.9595 - val_loss: 1.2512 - val_acc: 0.7268
#
# Epoch 00124: val_acc did not improve from 0.73428
# Epoch 125/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1068 - acc: 0.9613 - val_loss: 1.2294 - val_acc: 0.7241
#
# Epoch 00125: val_acc did not improve from 0.73428
# Epoch 126/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1037 - acc: 0.9635 - val_loss: 1.3196 - val_acc: 0.7092
#
# Epoch 00126: val_acc did not improve from 0.73428
# Epoch 127/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1092 - acc: 0.9609 - val_loss: 1.2691 - val_acc: 0.7174
#
# Epoch 00127: val_acc did not improve from 0.73428
# Epoch 128/150
# 198/198 [==============================] - 488s 2s/step - loss: 0.1039 - acc: 0.9621 - val_loss: 1.2945 - val_acc: 0.7173
#
# Epoch 00128: val_acc did not improve from 0.73428
# Epoch 129/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.0973 - acc: 0.9655 - val_loss: 1.3013 - val_acc: 0.7177
#
# Epoch 00129: val_acc did not improve from 0.73428
# Epoch 130/150
# 198/198 [==============================] - 487s 2s/step - loss: 0.1070 - acc: 0.9610 - val_loss: 1.2968 - val_acc: 0.7240
#
# Epoch 00130: val_acc did not improve from 0.73428
# Epoch 131/150
# 198/198 [==============================] - 484s 2s/step - loss: 0.0997 - acc: 0.9646 - val_loss: 1.3098 - val_acc: 0.7179
#
# Epoch 00131: val_acc did not improve from 0.73428
# Epoch 132/150
# 198/198 [==============================] - 489s 2s/step - loss: 0.1011 - acc: 0.9633 - val_loss: 1.3153 - val_acc: 0.7218
#
# Epoch 00132: val_acc did not improve from 0.73428
# Epoch 133/150
# 198/198 [==============================] - 623s 3s/step - loss: 0.1025 - acc: 0.9641 - val_loss: 1.2459 - val_acc: 0.7233
#
# Epoch 00133: val_acc did not improve from 0.73428
# Epoch 134/150
# 198/198 [==============================] - 795s 4s/step - loss: 0.0951 - acc: 0.9655 - val_loss: 1.2852 - val_acc: 0.7217
#
# Epoch 00134: val_acc did not improve from 0.73428
# Epoch 135/150
# 198/198 [==============================] - 659s 3s/step - loss: 0.0945 - acc: 0.9656 - val_loss: 1.2885 - val_acc: 0.7140
#
# Epoch 00135: val_acc did not improve from 0.73428
# Epoch 136/150
# 198/198 [==============================] - 585s 3s/step - loss: 0.0973 - acc: 0.9646 - val_loss: 1.2991 - val_acc: 0.7207
#
# Epoch 00136: val_acc did not improve from 0.73428
# Epoch 137/150
# 198/198 [==============================] - 486s 2s/step - loss: 0.0978 - acc: 0.9655 - val_loss: 1.3188 - val_acc: 0.7086
#
# Epoch 00137: val_acc did not improve from 0.73428
# Epoch 138/150
# 198/198 [==============================] - 475s 2s/step - loss: 0.0955 - acc: 0.9658 - val_loss: 1.3511 - val_acc: 0.7164
#
# Epoch 00138: val_acc did not improve from 0.73428
# Epoch 139/150
# 198/198 [==============================] - 474s 2s/step - loss: 0.0904 - acc: 0.9682 - val_loss: 1.3353 - val_acc: 0.7128
#
# Epoch 00139: val_acc did not improve from 0.73428
# Epoch 140/150
# 198/198 [==============================] - 472s 2s/step - loss: 0.0944 - acc: 0.9653 - val_loss: 1.3071 - val_acc: 0.7276
#
# Epoch 00140: val_acc did not improve from 0.73428
# Epoch 141/150
# 198/198 [==============================] - 474s 2s/step - loss: 0.0889 - acc: 0.9678 - val_loss: 1.2527 - val_acc: 0.7320
#
# Epoch 00141: val_acc did not improve from 0.73428
# Epoch 142/150
# 198/198 [==============================] - 477s 2s/step - loss: 0.0929 - acc: 0.9672 - val_loss: 1.2857 - val_acc: 0.7330
#
# Epoch 00142: val_acc did not improve from 0.73428
# Epoch 143/150
# 198/198 [==============================] - 476s 2s/step - loss: 0.0869 - acc: 0.9684 - val_loss: 1.3214 - val_acc: 0.7272
#
# Epoch 00143: val_acc did not improve from 0.73428
# Epoch 144/150
# 198/198 [==============================] - 485s 2s/step - loss: 0.0901 - acc: 0.9674 - val_loss: 1.2473 - val_acc: 0.7181
#
# Epoch 00144: val_acc did not improve from 0.73428
# Epoch 145/150
# 198/198 [==============================] - 785s 4s/step - loss: 0.0851 - acc: 0.9688 - val_loss: 1.3512 - val_acc: 0.7302
#
# Epoch 00145: val_acc did not improve from 0.73428
# Epoch 146/150
# 198/198 [==============================] - 785s 4s/step - loss: 0.0885 - acc: 0.9676 - val_loss: 1.3392 - val_acc: 0.7287
#
# Epoch 00146: val_acc did not improve from 0.73428
# Epoch 147/150
# 198/198 [==============================] - 548s 3s/step - loss: 0.0761 - acc: 0.9721 - val_loss: 1.3787 - val_acc: 0.7233
#
# Epoch 00147: val_acc did not improve from 0.73428
# Epoch 148/150
# 198/198 [==============================] - 469s 2s/step - loss: 0.0820 - acc: 0.9709 - val_loss: 1.3970 - val_acc: 0.7243
#
# Epoch 00148: val_acc did not improve from 0.73428
# Epoch 149/150
# 198/198 [==============================] - 571s 3s/step - loss: 0.0807 - acc: 0.9715 - val_loss: 1.3527 - val_acc: 0.7192
#
# Epoch 00149: val_acc did not improve from 0.73428
# Epoch 150/150
# 198/198 [==============================] - 471s 2s/step - loss: 0.0808 - acc: 0.9718 - val_loss: 1.3301 - val_acc: 0.7287
#
# Epoch 00150: val_acc did not improve from 0.73428
# CPU times: user 4d 21h 59min 52s, sys: 13h 22min 52s, total: 5d 11h 22min 45s
# Wall time: 1d 50min 45s

# %%
# serialize model structure to JSON
model_json = model.to_json()
with open("model_7c_150e.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ## Analyze the result

# %%
# plot the evolution of Loss and Acuracy on the train and validation sets

import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['acc'], label='Training Accuracy')
plt.plot(history.history['val_acc'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
validation_generator.n
# Out:
# 6229

# %%
validation_generator.batch_size
# Out:
# 128

# %%
from sklearn.metrics import classification_report, confusion_matrix

steps = validation_generator.n//validation_generator.batch_size+1
predictions = model.predict_generator(generator=validation_generator, steps=steps)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = validation_generator.classes

cnf_matrix = confusion_matrix(y_test, y_pred)

cnf_matrix
# Out:
# array([[ 38,   0,   0,  66,  55, 145, 656],
#        [ 86,   0,   1,  15,  18,  18,  30],
#        [ 81,   0,   0,  10,  14,  21,   5],
#        [424, 168, 132, 802, 121, 132,  46],
#        [ 42,   1,   1, 894, 168,  76,  34],
#        [100,   1,   2, 139, 624, 233,  40],
#        [ 93,   2,   1,  71, 128, 476,  26]])

# %%
print(validation_generator.class_indices)
# Out:
# {'distracted': 2, 'surprise': 6, 'sad': 5, 'happy': 3, 'neutral': 4, 'angry': 0, 'confused': 1}

# %%
print(train_generator.class_indices)
# Out:
# {'distracted': 2, 'surprise': 6, 'sad': 5, 'happy': 3, 'neutral': 4, 'angry': 0, 'confused': 1}

# %%
class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.04      0.04      0.04       960
#     confused       0.00      0.00      0.00       168
#   distracted       0.00      0.00      0.00       131
#        happy       0.40      0.44      0.42      1825
#      neutral       0.15      0.14      0.14      1216
#          sad       0.21      0.20      0.21      1139
#     surprise       0.03      0.03      0.03       797
#
#     accuracy                           0.20      6236
#    macro avg       0.12      0.12      0.12      6236
# weighted avg       0.20      0.20      0.20      6236

# %%
# show the confusion matrix of our predictions

# compute predictions
# predictions = model.predict_generator(generator=validation_generator, steps=57.484375)
# y_pred = [np.argmax(probas) for probas in predictions]
# y_test = validation_generator.classes
class_names = validation_generator.class_indices.keys()

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()
