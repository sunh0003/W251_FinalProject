# %%
import numpy as np
import os
from keras.preprocessing.image import load_img, img_to_array
# Out:
# Using TensorFlow backend.

# %%
base_path = "/notebooks/data/"

# %%
os.listdir(base_path + "train/happy")
# Out:
# ['31035.jpg',
#  '2900.jpg',
#  '25476.jpg',
#  '22294.jpg',
#  '31456.jpg',
#  '30670.jpg',
#  '32425.jpg',
#  '29606.jpg',
#  '21303.jpg',
#  '15127.jpg',
#  '4104.jpg',
#  '4333.jpg',
#  '18086.jpg',
#  '25051.jpg',
#  '27743.jpg',
#  '22686.jpg',
#  '6432.jpg',
#  '32162.jpg',
#  '7006.jpg',
#  '23087.jpg',
#  '12279.jpg',
#  '26528.jpg',
#  '31709.jpg',
#  '13375.jpg',
#  '27676.jpg',
#  '5604.jpg',
#  '26870.jpg',
#  '6363.jpg',
#  '20683.jpg',
#  '11720.jpg',
#  '4163.jpg',
#  '3760.jpg',
#  '17649.jpg',
#  '3483.jpg',
#  '16934.jpg',
#  '4962.jpg',
#  '17221.jpg',
#  '34893.jpg',
#  '10587.jpg',
#  '34394.jpg',
#  '7706.jpg',
#  '1936.jpg',
#  '29355.jpg',
#  '25205.jpg',
#  '7657.jpg',
#  '7013.jpg',
#  '14662.jpg',
#  '6505.jpg',
#  '15838.jpg',
#  '25111.jpg',
#  '33906.jpg',
#  '9772.jpg',
#  '3116.jpg',
#  '4323.jpg',
#  '26241.jpg',
#  '33476.jpg',
#  '10920.jpg',
#  '27166.jpg',
#  '8374.jpg',
#  '2547.jpg',
#  '19971.jpg',
#  '8737.jpg',
#  '26290.jpg',
# ...

# %%
img = load_img(base_path + "train/happy/" +os.listdir(base_path + "train/happy")[0], target_size=(48, 48))
img
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7EFFF40B0208>

# %%
data = img_to_array(img)
data.shape
# Out:
# (48, 48, 3)

# %%
type(data)
# Out:
# numpy.ndarray
