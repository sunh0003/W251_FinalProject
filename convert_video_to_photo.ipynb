# %% [markdown]
# # confused

# %%
import cv2
vidcap = cv2.VideoCapture('IMG_9408.MOV')
success,image = vidcap.read()
count = 0
while success:
    cv2.imwrite("confused%d.jpg" % count, image)     # save frame as JPEG file      
    success,image = vidcap.read()
    print('Read a new frame: ', success)
    count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# !pwd
# Out:
# /Users/KirbyMac/Desktop/BerkeleyClass/W251/W251_FinalProject

# %%
import os
conf_list=os.listdir("/Users/KirbyMac/Desktop/BerkeleyClass/W251/W251_FinalProject")
conf_list1=[]
for file in conf_list:
    if file.endswith(".jpg"):
        conf_list1.append(file)
print(len(conf_list))
print(len(conf_list1))
# Out:
# 1000
# 994

# %%
import cv2

im = Image.open(conf_list1[0])

    #rotate image by 90 degrees
angle = 270
out = im.rotate(angle, expand=True)
out.save('1'+conf_list[0])

img = Image.open('1'+conf_list[0]).convert('LA')
(left, upper, right, lower) = (0, 420, 1080, 1700)
img1 = img.crop((left, upper, right, lower))
img1 = img1.resize((48,48))

img1.save('3'+conf_list[0]+'.png')

# width height = im.size  
  
# # Setting the points for cropped image  
# left = 0
# top = height / 5
# right = 1080+(1920-1080)/2
# bottom = (1920-1080)/2
  
# # Cropped image of above dimension  
# # (It will not change orginal image)  
# im1 = im.crop((left, top, right, bottom)) 
# newsize = (48, 48) 
# im1 = im1.resize(newsize) 
# # Shows the image in image viewer  
# im1.show()

# %%
from PIL import Image

for file in conf_list1:
    im = Image.open(file)

    #rotate image by 90 degrees
    angle = 270
    out = im.rotate(angle, expand=True)
    #img = Image.open(out).convert('LA')
    out.save('1'+file)

    img = Image.open('1'+ file).convert('LA')
    (left, upper, right, lower) = (0, 420, 1080, 1700)
    img1 = img.crop((left, upper, right, lower))
    img1 = img1.resize((48,48))
    img1.save("2"+file+'.png')

# %% [markdown]
# # disctracted

# %%
import cv2
vidcap = cv2.VideoCapture('IMG_9407.MOV')
success,image = vidcap.read()
count = 0
while success:
    cv2.imwrite("distracted%d.jpg" % count, image)     # save frame as JPEG file      
    success,image = vidcap.read()
    print('Read a new frame: ', success)
    count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
import os
file_list=os.listdir("/Users/KirbyMac/Desktop/BerkeleyClass/W251/W251_FinalProject")
dist_list1=[]
for file in file_list:
    if file.startswith("distracted"):
        dist_list1.append(file)
print(len(file_list))
print(len(dist_list1))
# Out:
# 4024
# 1032

# %%
dist_list1
# Out:
# ['distracted492.jpg',
#  'distracted486.jpg',
#  'distracted451.jpg',
#  'distracted337.jpg',
#  'distracted323.jpg',
#  'distracted445.jpg',
#  'distracted479.jpg',
#  'distracted690.jpg',
#  'distracted848.jpg',
#  'distracted684.jpg',
#  'distracted874.jpg',
#  'distracted5.jpg',
#  'distracted860.jpg',
#  'distracted135.jpg',
#  'distracted653.jpg',
#  'distracted647.jpg',
#  'distracted121.jpg',
#  'distracted109.jpg',
#  'distracted928.jpg',
#  'distracted900.jpg',
#  'distracted914.jpg',
#  'distracted727.jpg',
#  'distracted733.jpg',
#  'distracted280.jpg',
#  'distracted294.jpg',
#  'distracted525.jpg',
#  'distracted243.jpg',
#  'distracted257.jpg',
#  'distracted531.jpg',
#  'distracted519.jpg',
#  'distracted17.jpg',
#  'distracted16.jpg',
#  'distracted518.jpg',
#  'distracted256.jpg',
#  'distracted530.jpg',
#  'distracted524.jpg',
#  'distracted242.jpg',
#  'distracted295.jpg',
#  'distracted281.jpg',
#  'distracted732.jpg',
#  'distracted726.jpg',
# ...

# %%
for file in dist_list1:
    im = Image.open(file)

    #rotate image by 90 degrees
    angle = 270
    out = im.rotate(angle, expand=True)
    #img = Image.open(out).convert('LA')
    out.save('1'+file)

    img = Image.open('1'+ file).convert('LA')
    (left, upper, right, lower) = (0, 420, 1080, 1700)
    img1 = img.crop((left, upper, right, lower))
    img1 = img1.resize((48,48))
    img1.save("2"+file+'.png')
